# %% [markdown]
# # Creating an agent class
# ### that has the propeties of looking the neighbours & has its what type and the position

# %%
class Agent:
    def __init__(self,agent_type,position):
        self.agent_type = agent_type
        self.position = position   
    def display(self):
        print("Agent type",self.agent_type)
        print("Agent Position",self.position)
    def check_neighbours(self,grid):
        # the characteristics of the neighbours to be defined later
        neighors =[]
        row, col = self.position
        
        #formation o the grid
        for dr in [-1,0,1]:
            for dc in [-1,0,1]:
                if dr == 0 and dc == 0:
                    continue
                    
                #check for the neighours position 
                new_row = row + dr
                new_col = row + dc
                
                # check the overall grid and append the value of the neighbour
                if 0 <= new_row < len(grid) and new_col < len(grid[0]):
                    neighbors.append(grid[new_row][new_col])
        return neighbour

# %%
agent1 = Agent("Red",(2,3))
neighbours = agent1.check_neighbours(grid)
print(neighbour)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 2
#       1 agent1 = Agent("Red",(2,3))
# ----> 2 neighbours = agent1.check_neighbours(grid)
#       3 print(neighbour)
#
# AttributeError: 'Agent' object has no attribute 'check_neighbours'

# %%
agent2 = Agent("Blue",(4,1))
agent2.display()
# Out:
# Agent type Blue
# Agent Position (4, 1)
